# %%
import pymedtermino
pymedtermino.LANGUAGE = "en"
pymedtermino.REMOVE_SUPPRESSED_CONCEPTS = True
pymedtermino.REMOVE_SUPPRESSED_TERMS = True
pymedtermino.REMOVE_SUPPRESSED_RELATIONS = True

# %%
from pymedtermino import *
from pymedtermino.snomedct import *

# %%
SNOMEDCT.search("^aspirin$")
# Out:
# [SNOMEDCT[7947003]  # Product containing aspirin (medicinal product),
#  SNOMEDCT[26047008]  # Aspirin tolerance test (procedure),
#  SNOMEDCT[36206007]  # Salicylate measurement (procedure),
#  SNOMEDCT[134394002]  # Aspirin not indicated (situation),
#  SNOMEDCT[135800003]  # Aspirin indicated (situation),
#  SNOMEDCT[235022008]  # Aspirin burn of oral mucosa (disorder),
#  SNOMEDCT[241949004]  # Aspirin-induced anaphylactoid reaction (disorder),
#  SNOMEDCT[241960008]  # Aspirin-induced angioedema-urticaria (disorder),
#  SNOMEDCT[243195000]  # Aspirin desensitization therapy (regime/therapy),
#  SNOMEDCT[275931000]  # Aspirin prophylaxis for ischemic heart disease (procedure),
#  SNOMEDCT[290146003]  # Aspirin poisoning of undetermined intent (disorder),
#  SNOMEDCT[292044008]  # Aspirin adverse reaction (disorder),
#  SNOMEDCT[293586001]  # Allergy to aspirin (finding),
#  SNOMEDCT[295135004]  # Aspirin overdose (disorder),
#  SNOMEDCT[295137007]  # Aspirin overdose of undetermined intent (disorder),
#  SNOMEDCT[312451002]  # Aspirin prophylaxis contra-indicated (situation),
#  SNOMEDCT[312452009]  # Aspirin prophylaxis (procedure),
#  SNOMEDCT[315023008]  # Aspirin prophylaxis refused (situation),
#  SNOMEDCT[319773006]  # Product containing precisely aspirin 75 milligram/1 each conventional release orodispersible tablet (clinical drug),
#  SNOMEDCT[319775004]  # Product containing precisely aspirin 75 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[319781007]  # Product containing precisely aspirin 75 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[322225002]  # Product containing precisely aspirin 300 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[322232006]  # Product containing precisely aspirin 300 milligram/1 each conventional release rectal suppository (clinical drug),
#  SNOMEDCT[322233001]  # Product containing precisely aspirin 150 milligram/1 each conventional release rectal suppository (clinical drug),
#  SNOMEDCT[322784004]  # Product containing precisely aspirin DL-lysine 900 milligram and metoclopramide hydrochloride 10 milligram/1 sachet conventional release oral powder (clinical drug),
#  SNOMEDCT[329525004]  # Product containing precisely aspirin 300 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[347070003]  # Product containing precisely aspirin 500 milligram and glycine 133 milligram/1 each conventional release orodispersible tablet (clinical drug),
#  SNOMEDCT[7248001]  # Poisoning caused by salicylate (disorder),
#  SNOMEDCT[370164001]  # Product containing precisely aspirin 81 milligram/1 each conventional release chewable tablet (clinical drug),
#  SNOMEDCT[370166004]  # Product containing precisely aspirin 325 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[370168003]  # Product containing precisely aspirin 165 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[370169006]  # Product containing precisely aspirin 325 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[370176001]  # Product containing precisely aspirin 120 milligram/1 each conventional release rectal suppository (clinical drug),
#  SNOMEDCT[370177005]  # Product containing precisely aspirin 200 milligram/1 each conventional release rectal suppository (clinical drug),
#  SNOMEDCT[370178000]  # Product containing precisely aspirin 600 milligram/1 each conventional release rectal suppository (clinical drug),
#  SNOMEDCT[371226001]  # Product containing precisely aspirin 325 milligram and butalbital 50 milligram and caffeine 40 milligram and codeine phosphate 30 milligram/1 each conventional release oral capsule (clinical drug),
#  SNOMEDCT[374744009]  # Product containing precisely aspirin 800 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[376250003]  # Product containing precisely aspirin 975 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377193004]  # Product containing precisely aspirin 325 milligram and butalbital 50 milligram and caffeine 40 milligram/1 each conventional release oral capsule (clinical drug),
#  SNOMEDCT[377194005]  # Product containing precisely aspirin 325 milligram and butalbital 50 milligram and caffeine 40 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377195006]  # Product containing precisely aspirin 356.4 milligram and caffeine 30 milligram and dihydrocodeine tartrate 16 milligram/1 each conventional release oral capsule (clinical drug),
#  SNOMEDCT[377196007]  # Product containing precisely aspirin 385 milligram and caffeine 30 milligram and orphenadrine citrate 25 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377197003]  # Product containing precisely aspirin 428 milligram and caffeine 30 milligram and orphenadrine citrate 25 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377199000]  # Product containing precisely aspirin 770 milligram and caffeine 60 milligram and orphenadrine citrate 50 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377200002]  # Product containing precisely aspirin 856 milligram and caffeine 60 milligram and orphenadrine citrate 50 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377201003]  # Product containing precisely aspirin 389 milligram and caffeine 32.4 milligram and dextropropoxyphene hydrochloride 65 milligram/1 each conventional release oral capsule (clinical drug),
#  SNOMEDCT[377202005]  # Product containing precisely aspirin 325 milligram and carisoprodol 200 milligram and codeine phosphate 16 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377203000]  # Product containing precisely aspirin 325 milligram and carisoprodol 200 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377204006]  # Product containing precisely aspirin 500 milligram and hydrocodone bitartrate 5 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377205007]  # Product containing precisely aspirin 325 milligram and meprobamate 200 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377206008]  # Product containing precisely aspirin 325 milligram and methocarbamol 400 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377207004]  # Product containing precisely aspirin 325 milligram and oxycodone hydrochloride 2.25 milligram and oxycodone terephthalate 190 microgram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[377209001]  # Product containing precisely aspirin 325 milligram and oxycodone hydrochloride 4.5 milligram and oxycodone terephthalate 380 microgram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[386038008]  # Product containing precisely aspirin 500 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[387458008]  # Aspirin (substance),
#  SNOMEDCT[398649009]  # Product containing aspirin and carisoprodol (medicinal product),
#  SNOMEDCT[398683002]  # Product containing aspirin and meprobamate (medicinal product),
#  SNOMEDCT[398767009]  # Product containing aspirin and glycine (medicinal product),
#  SNOMEDCT[398989001]  # Product containing aspirin and butalbital and caffeine (medicinal product),
#  SNOMEDCT[400487008]  # Product containing aspirin and metoclopramide (medicinal product),
#  SNOMEDCT[400489006]  # Product containing aspirin and methocarbamol (medicinal product),
#  SNOMEDCT[400819008]  # Product containing aspirin and papaveretum (medicinal product),
#  SNOMEDCT[404785009]  # Product containing precisely aspirin 300 milligram and codeine 8 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[405742008]  # Aspirin therapy finding (finding),
#  SNOMEDCT[405743003]  # Aspirin therapy location (finding),
#  SNOMEDCT[405744009]  # Aspirin given after arrival in hospital (situation),
#  SNOMEDCT[405745005]  # Aspirin given prior to arrival at hospital (situation),
#  SNOMEDCT[405747002]  # Aspirin not given (finding),
#  SNOMEDCT[407136004]  # Aspirin specific immunoglobulin E (substance),
#  SNOMEDCT[407674008]  # Aspirin-induced asthma (disorder),
#  SNOMEDCT[407681001]  # Aspirin specific immunoglobulin E antibody measurement (procedure),
#  SNOMEDCT[409311005]  # Product containing aspirin and pravastatin (medicinal product),
#  SNOMEDCT[409312003]  # Product containing precisely aspirin 81 milligram and pravastatin 20 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[409313008]  # Product containing precisely aspirin 81 milligram and pravastatin 40 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[409314002]  # Product containing precisely aspirin 81 milligram and pravastatin 80 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[409315001]  # Product containing precisely aspirin 325 milligram and pravastatin 80 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[409316000]  # Product containing precisely aspirin 325 milligram and pravastatin 40 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[409317009]  # Product containing precisely aspirin 325 milligram and pravastatin 20 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[412095002]  # Product containing aspirin and caffeine and cinnamedrine (medicinal product),
#  SNOMEDCT[412096001]  # Product containing aspirin and codeine (medicinal product),
#  SNOMEDCT[412568000]  # Product containing aspirin and caffeine and paracetamol (medicinal product),
#  SNOMEDCT[412569008]  # Product containing aspirin and caffeine (medicinal product),
#  SNOMEDCT[412575004]  # Product containing precisely aspirin 325 milligram and codeine 30 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[412576003]  # Product containing precisely aspirin 325 milligram and codeine 60 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[412647005]  # Product containing precisely aspirin 389 milligram and caffeine 32.4 milligram and dextropropoxyphene hydrochloride 32 milligram/1 each conventional release oral capsule (clinical drug),
#  SNOMEDCT[412566001]  # Product containing buffered aspirin (medicinal product),
#  SNOMEDCT[413586006]  # Product containing precisely aspirin 250 milligram and caffeine 65 milligram and paracetamol 250 milligram/1 each conventional release oral tablet (clinical drug),
#  SNOMEDCT[426365001]  # Buffered aspirin (substance),
#  SNOMEDCT[424102008]  # Product containing aspirin and paracetamol (medicinal product),
#  SNOMEDCT[319796006]  # Product containing aspirin and dipyridamole (medicinal product),
#  SNOMEDCT[432909005]  # Aspirin given (situation),
#  SNOMEDCT[10692681000119108]  # Aspirin exacerbated respiratory disease (disorder),
#  SNOMEDCT[717854002]  # Aspirin therapy (procedure),
#  SNOMEDCT[350314003]  # Product containing aspirin in rectal dose form (medicinal product form),
#  SNOMEDCT[358427004]  # Product containing aspirin in oral dose form (medicinal product form),
#  SNOMEDCT[735135008]  # Aspirin DL-lysine (substance),
#  SNOMEDCT[764369003]  # Product containing aspirin and omeprazole in oral dose form (medicinal product form),
#  SNOMEDCT[765559002]  # Product containing precisely aspirin 975 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[765570009]  # Product containing precisely aspirin 81 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[765676008]  # Product containing precisely aspirin 650 milligram/1 each gastro-resistant oral tablet (clinical drug),
#  SNOMEDCT[763644001]  # Product containing aspirin and omeprazole (medicinal product),
#  SNOMEDCT[764567002]  # Product containing aspirin and pentazocine (medicinal product),
#  SNOMEDCT[764599008]  # Product containing aspirin and cyclizine (medicinal product),
#  SNOMEDCT[766001006]  # Product containing precisely aspirin 25 milligram and dipyridamole 200 milligram/1 each prolonged-release oral capsule (clinical drug),
#  SNOMEDCT[767742009]  # Product containing aspirin and dipyridamole in oral dose form (medicinal product form),
#  SNOMEDCT[767897005]  # Product containing aspirin and caffeine and paracetamol in oral dose form (medicinal product form),
#  SNOMEDCT[767898000]  # Product containing aspirin and hydrocodone in oral dose form (medicinal product form),
#  SNOMEDCT[767899008]  # Product containing aspirin and pravastatin in oral dose form (medicinal product form),
#  SNOMEDCT[767900003]  # Product containing aspirin and carisoprodol in oral dose form (medicinal product form),
#  SNOMEDCT[767901004]  # Product containing aspirin and meprobamate in oral dose form (medicinal product form),
#  SNOMEDCT[767902006]  # Product containing aspirin and methocarbamol in oral dose form (medicinal product form),
#  SNOMEDCT[767919008]  # Product containing aspirin and butalbital and caffeine in oral dose form (medicinal product form),
#  SNOMEDCT[767920002]  # Product containing aspirin and butalbital and caffeine and codeine (medicinal product),
#  SNOMEDCT[767922005]  # Product containing aspirin and butalbital and caffeine and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[767923000]  # Product containing aspirin and oxycodone (medicinal product),
#  SNOMEDCT[767924006]  # Product containing aspirin and oxycodone in oral dose form (medicinal product form),
#  SNOMEDCT[767925007]  # Product containing aspirin and carisoprodol and codeine (medicinal product),
#  SNOMEDCT[767926008]  # Product containing aspirin and carisoprodol and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[767927004]  # Product containing aspirin and caffeine and orphenadrine in oral dose form (medicinal product form),
#  SNOMEDCT[767929001]  # Product containing aspirin and caffeine and dihydrocodeine (medicinal product),
#  SNOMEDCT[767930006]  # Product containing aspirin and caffeine and dihydrocodeine in oral dose form (medicinal product form),
#  SNOMEDCT[768404004]  # Product containing aspirin and hydrocodone (medicinal product),
#  SNOMEDCT[412458007]  # Product containing aspirin and caffeine and orphenadrine (medicinal product),
#  SNOMEDCT[770875005]  # Product containing aspirin and isosorbide (medicinal product),
#  SNOMEDCT[772317006]  # Product containing aspirin and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[772318001]  # Product containing aspirin and caffeine and dextropropoxyphene in oral dose form (medicinal product form),
#  SNOMEDCT[772319009]  # Product containing aspirin and metoclopramide in oral dose form (medicinal product form),
#  SNOMEDCT[772916008]  # Product containing aspirin and caffeine and dextropropoxyphene (medicinal product),
#  SNOMEDCT[774656009]  # Product containing only aspirin (medicinal product),
#  SNOMEDCT[774657000]  # Product containing only aspirin and butalbital and caffeine (medicinal product),
#  SNOMEDCT[774658005]  # Product containing only aspirin and butalbital and caffeine and codeine (medicinal product),
#  SNOMEDCT[774659002]  # Product containing only aspirin and caffeine (medicinal product),
#  SNOMEDCT[774660007]  # Product containing only aspirin and caffeine and cinnamedrine (medicinal product),
#  SNOMEDCT[774661006]  # Product containing only aspirin and caffeine and dextropropoxyphene (medicinal product),
#  SNOMEDCT[774662004]  # Product containing only aspirin and caffeine and dihydrocodeine (medicinal product),
#  SNOMEDCT[774663009]  # Product containing only aspirin and caffeine and orphenadrine (medicinal product),
#  SNOMEDCT[774664003]  # Product containing only aspirin and caffeine and paracetamol (medicinal product),
#  SNOMEDCT[774665002]  # Product containing only aspirin and carisoprodol (medicinal product),
#  SNOMEDCT[774666001]  # Product containing only aspirin and carisoprodol and codeine (medicinal product),
#  SNOMEDCT[774667005]  # Product containing only aspirin and codeine (medicinal product),
#  SNOMEDCT[774668000]  # Product containing only aspirin and cyclizine (medicinal product),
#  SNOMEDCT[774669008]  # Product containing only aspirin and dipyridamole (medicinal product),
#  SNOMEDCT[774670009]  # Product containing only aspirin and glycine (medicinal product),
#  SNOMEDCT[774671008]  # Product containing only aspirin and hydrocodone (medicinal product),
#  SNOMEDCT[774672001]  # Product containing only aspirin and isosorbide (medicinal product),
#  SNOMEDCT[774673006]  # Product containing only aspirin and meprobamate (medicinal product),
#  SNOMEDCT[774674000]  # Product containing only aspirin and methocarbamol (medicinal product),
#  SNOMEDCT[774675004]  # Product containing only aspirin and metoclopramide (medicinal product),
#  SNOMEDCT[774676003]  # Product containing only aspirin and omeprazole (medicinal product),
#  SNOMEDCT[774677007]  # Product containing only aspirin and oxycodone (medicinal product),
#  SNOMEDCT[774678002]  # Product containing only aspirin and papaveretum (medicinal product),
#  SNOMEDCT[774679005]  # Product containing only aspirin and paracetamol (medicinal product),
#  SNOMEDCT[774680008]  # Product containing only aspirin and pentazocine (medicinal product),
#  SNOMEDCT[774681007]  # Product containing only aspirin and pravastatin (medicinal product),
#  SNOMEDCT[778360008]  # Product containing only aspirin and butalbital and caffeine and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[778361007]  # Product containing only aspirin and butalbital and caffeine in oral dose form (medicinal product form),
#  SNOMEDCT[778362000]  # Product containing only aspirin and caffeine and dextropropoxyphene in oral dose form (medicinal product form),
#  SNOMEDCT[778363005]  # Product containing only aspirin and caffeine and dihydrocodeine in oral dose form (medicinal product form),
#  SNOMEDCT[778364004]  # Product containing only aspirin and caffeine and orphenadrine in oral dose form (medicinal product form),
#  SNOMEDCT[778365003]  # Product containing only aspirin and caffeine and paracetamol in oral dose form (medicinal product form),
#  SNOMEDCT[778366002]  # Product containing only aspirin and carisoprodol and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[778367006]  # Product containing only aspirin and carisoprodol in oral dose form (medicinal product form),
#  SNOMEDCT[778368001]  # Product containing only aspirin and codeine in oral dose form (medicinal product form),
#  SNOMEDCT[778369009]  # Product containing only aspirin and dipyridamole in oral dose form (medicinal product form),
#  SNOMEDCT[778370005]  # Product containing only aspirin and hydrocodone in oral dose form (medicinal product form),
#  SNOMEDCT[778371009]  # Product containing only aspirin and meprobamate in oral dose form (medicinal product form),
#  SNOMEDCT[778372002]  # Product containing only aspirin and methocarbamol in oral dose form (medicinal product form),
#  SNOMEDCT[778373007]  # Product containing only aspirin and metoclopramide in oral dose form (medicinal product form),
#  SNOMEDCT[778374001]  # Product containing only aspirin and omeprazole in oral dose form (medicinal product form),
#  SNOMEDCT[778375000]  # Product containing only aspirin and oxycodone in oral dose form (medicinal product form),
#  SNOMEDCT[778376004]  # Product containing only aspirin and pravastatin in oral dose form (medicinal product form),
#  SNOMEDCT[778377008]  # Product containing only aspirin in oral dose form (medicinal product form),
#  SNOMEDCT[778378003]  # Product containing only aspirin in rectal dose form (medicinal product form),
#  SNOMEDCT[785016007]  # Product containing precisely aspirin 1.5 milligram/1 milliliter conventional release oral solution (clinical drug),
#  SNOMEDCT[785018008]  # Product containing precisely aspirin 2.5 milligram/1 milliliter conventional release oral solution (clinical drug),
#  SNOMEDCT[785412001]  # Product containing aspirin and glycine in oromucosal dose form (medicinal product form),
#  SNOMEDCT[785413006]  # Product containing aspirin in oromucosal dose form (medicinal product form),
#  SNOMEDCT[786109002]  # Product containing only aspirin and glycine in oromucosal dose form (medicinal product form),
#  SNOMEDCT[786110007]  # Product containing only aspirin in oromucosal dose form (medicinal product form)]

# %%
SNOMEDCT[387458008].terms
# Out:
# ['Aspirin (substance)', 'Aspirin', 'Acetylsalicylic acid']
